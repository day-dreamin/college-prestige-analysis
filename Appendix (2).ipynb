# %%
import requests
import pandas as pd
url = "https://meric.mo.gov/data/cost-living-data-series"

# Send a GET request to the URL
response = requests.get(url)
col_data = pd.read_html(response.text)
col_data = col_data[0]
col_data.to_csv('col.csv', index=False)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_52508\2802426434.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   col_data = pd.read_html(response.text)

# %%
col_data
# Out:
#    Rank                 State  Index  Grocery  Housing  Utilities  \
# 0     1         West Virginia   84.3     98.9     60.2       98.5
# 1     2              Oklahoma   85.3     94.6     68.6       93.4
# 2     3                Kansas   87.0     94.9     73.9       98.6
# 3     4               Alabama   87.6     96.5     68.5       99.4
# 4     5           Mississippi   87.7     95.4     74.3       87.0
# 5     6              Arkansas   88.5     94.6     74.4       91.8
# 6     7              Missouri   88.6     95.5     77.0       99.8
# 7     8                  Iowa   89.1     96.0     74.8       91.3
# 8     9               Indiana   90.3     97.4     76.2       89.1
# 9    10             Tennessee   90.8     96.6     83.7       87.8
# 10   11              Michigan   90.9     98.3     72.5       99.4
# 11   12               Georgia   90.9     96.6     78.5       97.6
# 12   13          South Dakota   91.2     95.8     86.2       83.5
# ...
